# %%
import pandas as pd
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn import linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import ensemble
from sklearn import tree
from sklearn import svm
from sklearn import neighbors
from sklearn import naive_bayes
import numpy as np
from sklearn.model_selection import train_test_split

# from sklearn.datasets import load_breast_cancer
data_df = pd.read_csv('/content/data.csv')
data_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# Treino (60%)
#
#
# Teste (40%)
#
# randomizado, mas não estratificado

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
#from sklearn.model_selection import StratifiedShuffleSplit

X = data_df.drop(['diagnosis' , 'id' , 'Unnamed: 32'] , axis =1)
y = data_df.diagnosis
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
def my_train_test_split(X, y, train_ratio, seed):
    qtd = X.shape[0]
    idx = np.random.RandomState(seed=seed).permutation(np.arange(qtd))
    qtd_train = int(qtd * train_ratio)
    idx_train = idx[:qtd_train]
    idx_test  = idx[qtd_train:]
    if type(X) == np.ndarray:    # NumPy Array
        X_train   = X[idx_train]
        X_test    = X[idx_test]
        y_train   = y[idx_train]
        y_test    = y[idx_test]
    else:                        # Pandas DataFrame
        X_train   = X.iloc[idx_train]
        X_test    = X.iloc[idx_test]
        y_train   = y.iloc[idx_train]
        y_test    = y.iloc[idx_test]
        
    return X_train, X_test, y_train, y_test

# %%
X_train , X_test , y_train , y_test = my_train_test_split(X, y , 0.6, 42)

# %%
modelos = {}
modelos['DT'] = tree.DecisionTreeClassifier()
modelos['SVM'] = svm.SVC()
modelos['KNN'] = neighbors.KNeighborsClassifier(n_neighbors=3)
modelos['LogReg'] = linear_model.LogisticRegression(multi_class='multinomial',solver='newton-cg')
modelos['NB'] = naive_bayes.GaussianNB()
modelos['SGD'] = linear_model.SGDClassifier()
modelos['RF'] = ensemble.RandomForestClassifier()
modelos['GB'] = ensemble.GradientBoostingClassifier()

# %%
algs = []
resultados_train = []
resultados_test = []

for modelo_str in modelos.keys(): 
  modelo = modelos[modelo_str]
  modelo.fit(X_train, y_train) 
  y_pred_train = modelo.predict(X_train)
  y_pred_test  = modelo.predict(X_test)
  acuracia_train = metrics.accuracy_score(y_train, y_pred_train)
  acuracia_test  = metrics.accuracy_score(y_test , y_pred_test)
  algs.append(modelo_str)
  resultados_train.append(round(acuracia_train,2))
  resultados_test.append(round(acuracia_test,2))

df_result = pd.DataFrame({'algs' : algs , 'acc_train' : resultados_train, 'acc_test' : resultados_test})
df_result
# Out:
#      algs  acc_train  acc_test
# 0      DT       1.00      0.93
# 1     SVM       0.92      0.88
# 2     KNN       0.96      0.91
# 3  LogReg       0.97      0.94
# 4      NB       0.95      0.93
# 5     SGD       0.92      0.90
# 6      RF       1.00      0.96
# 7      GB       1.00      0.96

# %% [markdown]
# Treino (60%)
#
#
# Teste (40%)
#
# randomizado e estratificado

# %% [markdown]
# **Usando o train_test_split do Scikit Learn, que por padrão já usa estratificação sobre os rótulos**.

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X, y, train_size = 0.6, random_state=42, stratify=y)

# %%
algs = []
resultados_train = []
resultados_test = []

for modelo_str in modelos.keys(): 
  modelo = modelos[modelo_str]
  modelo.fit(X_train_1, y_train_1) 
  y_pred_train = modelo.predict(X_train_1)
  y_pred_test  = modelo.predict(X_test_1)
  acuracia_train = metrics.accuracy_score(y_train_1, y_pred_train)
  acuracia_test  = metrics.accuracy_score(y_test_1 , y_pred_test)
  algs.append(modelo_str)
  resultados_train.append(round(acuracia_train,2))
  resultados_test.append(round(acuracia_test,2))

df_result1 = pd.DataFrame({'algs' : algs , 'acc_train' : resultados_train, 'acc_test' : resultados_test})
df_result1
# Out:
#      algs  acc_train  acc_test
# 0      DT       1.00      0.93
# 1     SVM       0.90      0.91
# 2     KNN       0.96      0.94
# 3  LogReg       0.96      0.95
# 4      NB       0.95      0.93
# 5     SGD       0.89      0.88
# 6      RF       1.00      0.96
# 7      GB       1.00      0.96

# %% [markdown]
# Treino (80%)
#
#
# Teste (20%)
#
# randomizado, mas não estratificado

# %%
X_train_2 , X_test_2 , y_train_2 , y_test_2 = my_train_test_split(X, y , 0.8, 42)

# %%
algs = []
resultados_train = []
resultados_test = []

for modelo_str in modelos.keys(): 
  modelo = modelos[modelo_str]
  modelo.fit(X_train_2, y_train_2) 
  y_pred_train = modelo.predict(X_train_2)
  y_pred_test  = modelo.predict(X_test_2)
  acuracia_train = metrics.accuracy_score(y_train_2, y_pred_train)
  acuracia_test  = metrics.accuracy_score(y_test_2 , y_pred_test)
  algs.append(modelo_str)
  resultados_train.append(round(acuracia_train,2))
  resultados_test.append(round(acuracia_test,2))

df_result2 = pd.DataFrame({'algs' : algs , 'acc_train' : resultados_train, 'acc_test' : resultados_test})
df_result2
# Out:
#      algs  acc_train  acc_test
# 0      DT       1.00      0.95
# 1     SVM       0.93      0.87
# 2     KNN       0.96      0.90
# 3  LogReg       0.97      0.92
# 4      NB       0.95      0.92
# 5     SGD       0.92      0.88
# 6      RF       1.00      0.96
# 7      GB       1.00      0.96

# %% [markdown]
# Treino (80%)
#
#
# Teste (20%)
#
# randomizado e estratificado

# %%
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)

# %%
algs = []
resultados_train = []
resultados_test = []

for modelo_str in modelos.keys(): 
  modelo = modelos[modelo_str]
  modelo.fit(X_train_3, y_train_3) 
  y_pred_train = modelo.predict(X_train_3)
  y_pred_test  = modelo.predict(X_test_3)
  acuracia_train = metrics.accuracy_score(y_train_3, y_pred_train)
  acuracia_test  = metrics.accuracy_score(y_test_3 , y_pred_test)
  algs.append(modelo_str)
  resultados_train.append(round(acuracia_train,2))
  resultados_test.append(round(acuracia_test,2))

df_result3 = pd.DataFrame({'algs' : algs , 'acc_train' : resultados_train, 'acc_test' : resultados_test})
df_result3
# Out:
#      algs  acc_train  acc_test
# 0      DT       1.00      0.93
# 1     SVM       0.92      0.90
# 2     KNN       0.96      0.92
# 3  LogReg       0.97      0.94
# 4      NB       0.94      0.94
# 5     SGD       0.85      0.86
# 6      RF       1.00      0.97
# 7      GB       1.00      0.96
